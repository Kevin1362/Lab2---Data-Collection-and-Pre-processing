# %% [markdown]
# # Data Collection and Pre-Processing Lab – E-Commerce Dataset

# %% [markdown]
# ## Step 1 – Hello, Data!

# %%
import pandas as pd

df_raw = pd.read_csv('data/sales_500.csv')
df_raw.head(400)
# Out:
#            date customer_id     product    price  quantity coupon_code  \
# 0    2024-03-13    CUST1000     Monitor   276.34         3   WELCOME15
# 1    2024-03-09    CUST1001    Keyboard   662.10         1   DISCOUNT5
# 2    2024-02-25    CUST1002  Headphones   609.79         4   WELCOME15
# 3    2024-03-08    CUST1003    Keyboard   931.46         1       OFF20
# 4    2024-06-05    CUST1004    Keyboard   959.94         1   DISCOUNT5
# ..          ...         ...         ...      ...       ...         ...
# 395  2024-01-07    CUST1395       Phone  1228.57         4      SAVE10
# 396  2024-03-04    CUST1396  Headphones   669.92         1      SAVE10
# 397  2024-03-27    CUST1397       Phone   577.88         4         NaN
# 398  2024-01-18    CUST1398      Laptop   704.77         1         NaN
# 399  2024-03-16    CUST1399    Keyboard   466.04         2      SAVE10
#
#     shipping_city
# 0         Calgary
# 1         Toronto
# 2         Toronto
# 3          Ottawa
# 4         Toronto
# ..            ...
# 395       Toronto
# 396       Toronto
# 397      Montreal
# 398        Ottawa
# 399       Calgary
#
# [400 rows x 7 columns]

# %% [markdown]
# ## : Merge `sales_500.csv` with Kaggle dataset
#
# In this lab, we will also merge the original sales file (`sales_500.csv`) with a Kaggle retail dataset (`retail_sales_dataset.csv`).
# We will **map Kaggle columns** to match the lab schema, then **append rows** and continue the same cleaning steps on the combined dataset.

# %%
# Load Kaggle dataset (make sure this file exists in the /data folder)
df_kaggle_raw = pd.read_csv('data/retail_sales_dataset.csv')

# Clean Kaggle column names
df_kaggle = df_kaggle_raw.copy()
df_kaggle.columns = [c.strip().lower().replace(' ', '_') for c in df_kaggle.columns]

# Map Kaggle columns -> Lab columns
# Kaggle columns: date, customer_id, product_category, quantity, price_per_unit, total_amount
df_kaggle_mapped = pd.DataFrame({
    'date': df_kaggle.get('date'),
    'customer_id': df_kaggle.get('customer_id'),
    'product': df_kaggle.get('product_category'),
    'price': df_kaggle.get('price_per_unit'),
    'quantity': df_kaggle.get('quantity'),
    'coupon_code': pd.NA,           # not available in Kaggle dataset
    'shipping_city': pd.NA          # not available in Kaggle dataset
})

# Align columns (union) and append rows
all_cols = sorted(set(df_raw.columns).union(set(df_kaggle_mapped.columns)))
df_raw_aligned = df_raw.reindex(columns=all_cols)
df_kaggle_aligned = df_kaggle_mapped.reindex(columns=all_cols)

df_raw = pd.concat([df_raw_aligned, df_kaggle_aligned], ignore_index=True)

print('✅ Merge complete!')
print('Combined dataset shape:', df_raw.shape)
df_raw.head()
# Out:
# ✅ Merge complete!
# Combined dataset shape: (1500, 7)
#   coupon_code customer_id        date   price     product  quantity  \
# 0   WELCOME15    CUST1000  2024-03-13  276.34     Monitor         3
# 1   DISCOUNT5    CUST1001  2024-03-09  662.10    Keyboard         1
# 2   WELCOME15    CUST1002  2024-02-25  609.79  Headphones         4
# 3       OFF20    CUST1003  2024-03-08  931.46    Keyboard         1
# 4   DISCOUNT5    CUST1004  2024-06-05  959.94    Keyboard         1
#
#   shipping_city
# 0       Calgary
# 1       Toronto
# 2       Toronto
# 3        Ottawa
# 4       Toronto

# %% [markdown]
# ## Step 2 – Pick the Right Container
# A dictionary is appropriate because it allows fast key-based lookups
# (e.g., customer_id → transactions) and flexible mutation during cleaning.
# Namedtuples are immutable and better suited for fixed schemas, while sets
# are useful only for uniqueness checks, not structured records.

# %% [markdown]
# ## Step 3 – Implement Functions and Data Structure

# %%
class TransactionCleaner:
    def __init__(self, df):
        self.df = df.copy()

    def clean(self):
        self.df = self.df.dropna(subset=['price', 'quantity'])
        self.df = self.df[self.df['quantity'] > 0]
        return self.df

    def total(self):
        return (self.df['price'] * self.df['quantity']).sum()

cleaner = TransactionCleaner(df_raw)
df_step3 = cleaner.clean()
cleaner.total()
# Out:
# np.float64(1396632.29)

# %% [markdown]
# ## Step 4 – Bulk Loaded

# %%
transactions_dict = df_step3.to_dict(orient='records')
transactions_dict[:499]
# Out:
# [{'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1000',
#   'date': '2024-03-13',
#   'price': 276.34,
#   'product': 'Monitor',
#   'quantity': 3,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1001',
#   'date': '2024-03-09',
#   'price': 662.1,
#   'product': 'Keyboard',
#   'quantity': 1,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1002',
#   'date': '2024-02-25',
#   'price': 609.79,
#   'product': 'Headphones',
#   'quantity': 4,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1003',
#   'date': '2024-03-08',
#   'price': 931.46,
#   'product': 'Keyboard',
#   'quantity': 1,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1004',
#   'date': '2024-06-05',
#   'price': 959.94,
#   'product': 'Keyboard',
#   'quantity': 1,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1005',
#   'date': '2024-06-14',
#   'price': 87.05,
#   'product': 'Phone',
#   'quantity': 4,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1006',
#   'date': '2024-03-12',
#   'price': 574.43,
#   'product': 'Headphones',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1007',
#   'date': '2024-04-03',
#   'price': 946.27,
#   'product': 'Headphones',
#   'quantity': 2,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1008',
#   'date': '2024-02-19',
#   'price': 764.64,
#   'product': 'Headphones',
#   'quantity': 4,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1009',
#   'date': '2024-04-15',
#   'price': 1287.6,
#   'product': 'Keyboard',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1010',
#   'date': '2024-03-20',
#   'price': 994.87,
#   'product': 'Monitor',
#   'quantity': 1,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1011',
#   'date': '2024-01-24',
#   'price': 261.14,
#   'product': 'Headphones',
#   'quantity': 4,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1012',
#   'date': '2024-03-23',
#   'price': 124.44,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1013',
#   'date': '2024-02-19',
#   'price': 970.78,
#   'product': 'Keyboard',
#   'quantity': 3,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1014',
#   'date': '2024-04-28',
#   'price': 59.24,
#   'product': 'Phone',
#   'quantity': 1,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1015',
#   'date': '2024-03-25',
#   'price': 886.95,
#   'product': 'Monitor',
#   'quantity': 4,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1016',
#   'date': '2024-02-24',
#   'price': 1411.54,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1017',
#   'date': '2024-06-06',
#   'price': 871.7,
#   'product': 'Mouse',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1018',
#   'date': '2024-03-26',
#   'price': 594.49,
#   'product': 'Phone',
#   'quantity': 3,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1019',
#   'date': '2024-06-14',
#   'price': 972.07,
#   'product': 'Monitor',
#   'quantity': 3,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1020',
#   'date': '2024-05-28',
#   'price': 698.21,
#   'product': 'Keyboard',
#   'quantity': 3,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1021',
#   'date': '2024-06-10',
#   'price': 827.51,
#   'product': 'Laptop',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1022',
#   'date': '2024-03-21',
#   'price': 1413.37,
#   'product': 'Monitor',
#   'quantity': 3,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1023',
#   'date': '2024-05-27',
#   'price': 591.43,
#   'product': 'Phone',
#   'quantity': 2,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1024',
#   'date': '2024-06-08',
#   'price': 1442.56,
#   'product': 'Mouse',
#   'quantity': 4,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1025',
#   'date': '2024-04-01',
#   'price': 1359.92,
#   'product': 'Keyboard',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1026',
#   'date': '2024-05-31',
#   'price': 309.77,
#   'product': 'Monitor',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1027',
#   'date': '2024-02-23',
#   'price': 122.65,
#   'product': 'Laptop',
#   'quantity': 1,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1028',
#   'date': '2024-02-21',
#   'price': 169.15,
#   'product': 'Laptop',
#   'quantity': 1,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1029',
#   'date': '2024-03-25',
#   'price': 46.97,
#   'product': 'Headphones',
#   'quantity': 1,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1030',
#   'date': '2024-05-16',
#   'price': 159.78,
#   'product': 'Headphones',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1031',
#   'date': '2024-02-08',
#   'price': 1030.85,
#   'product': 'Phone',
#   'quantity': 4,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1032',
#   'date': '2024-04-25',
#   'price': 125.36,
#   'product': 'Monitor',
#   'quantity': 4,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1033',
#   'date': '2024-04-13',
#   'price': 492.08,
#   'product': 'Monitor',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1034',
#   'date': '2024-02-19',
#   'price': 1270.42,
#   'product': 'Mouse',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1035',
#   'date': '2024-02-05',
#   'price': 54.44,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1036',
#   'date': '2024-05-21',
#   'price': 1225.41,
#   'product': 'Mouse',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1037',
#   'date': '2024-04-26',
#   'price': 437.15,
#   'product': 'Headphones',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1038',
#   'date': '2024-05-05',
#   'price': 194.88,
#   'product': 'Monitor',
#   'quantity': 3,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1039',
#   'date': '2024-04-24',
#   'price': 1051.17,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1040',
#   'date': '2024-05-24',
#   'price': 950.84,
#   'product': 'Laptop',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1041',
#   'date': '2024-04-23',
#   'price': 1318.66,
#   'product': 'Headphones',
#   'quantity': 2,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1042',
#   'date': '2024-06-12',
#   'price': 1107.91,
#   'product': 'Keyboard',
#   'quantity': 4,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1043',
#   'date': '2024-05-18',
#   'price': 1209.15,
#   'product': 'Headphones',
#   'quantity': 1,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1044',
#   'date': '2024-03-28',
#   'price': 437.41,
#   'product': 'Keyboard',
#   'quantity': 2,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1045',
#   'date': '2024-02-29',
#   'price': 282.61,
#   'product': 'Laptop',
#   'quantity': 2,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1046',
#   'date': '2024-01-18',
#   'price': 1130.91,
#   'product': 'Phone',
#   'quantity': 2,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1047',
#   'date': '2024-05-07',
#   'price': 1214.12,
#   'product': 'Monitor',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1048',
#   'date': '2024-01-07',
#   'price': 1485.95,
#   'product': 'Laptop',
#   'quantity': 3,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1049',
#   'date': '2024-01-05',
#   'price': 630.67,
#   'product': 'Monitor',
#   'quantity': 4,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1050',
#   'date': '2024-04-03',
#   'price': 570.59,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1051',
#   'date': '2024-05-01',
#   'price': 1169.09,
#   'product': 'Phone',
#   'quantity': 4,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1052',
#   'date': '2024-03-05',
#   'price': 524.39,
#   'product': 'Phone',
#   'quantity': 1,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1053',
#   'date': '2024-01-18',
#   'price': 1397.52,
#   'product': 'Laptop',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1054',
#   'date': '2024-06-18',
#   'price': 1290.45,
#   'product': 'Phone',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1055',
#   'date': '2024-04-19',
#   'price': 654.91,
#   'product': 'Keyboard',
#   'quantity': 3,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1056',
#   'date': '2024-03-04',
#   'price': 1131.29,
#   'product': 'Phone',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1057',
#   'date': '2024-03-23',
#   'price': 1136.72,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1058',
#   'date': '2024-05-16',
#   'price': 172.62,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1059',
#   'date': '2024-02-17',
#   'price': 1355.78,
#   'product': 'Monitor',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1060',
#   'date': '2024-03-24',
#   'price': 767.77,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1061',
#   'date': '2024-02-06',
#   'price': 1243.16,
#   'product': 'Keyboard',
#   'quantity': 2,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1062',
#   'date': '2024-04-15',
#   'price': 493.67,
#   'product': 'Headphones',
#   'quantity': 4,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1063',
#   'date': '2024-03-27',
#   'price': 1345.37,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1064',
#   'date': '2024-03-29',
#   'price': 596.02,
#   'product': 'Laptop',
#   'quantity': 3,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1065',
#   'date': '2024-04-02',
#   'price': 36.04,
#   'product': 'Monitor',
#   'quantity': 3,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1066',
#   'date': '2024-02-28',
#   'price': 1359.97,
#   'product': 'Phone',
#   'quantity': 4,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1067',
#   'date': '2024-04-07',
#   'price': 155.1,
#   'product': 'Monitor',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1068',
#   'date': '2024-01-08',
#   'price': 492.58,
#   'product': 'Phone',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1069',
#   'date': '2024-01-13',
#   'price': 1426.09,
#   'product': 'Mouse',
#   'quantity': 3,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1070',
#   'date': '2024-02-13',
#   'price': 1426.9,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1071',
#   'date': '2024-06-20',
#   'price': 868.69,
#   'product': 'Mouse',
#   'quantity': 4,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1072',
#   'date': '2024-03-16',
#   'price': 955.12,
#   'product': 'Phone',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1073',
#   'date': '2024-01-10',
#   'price': 683.7,
#   'product': 'Monitor',
#   'quantity': 1,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1074',
#   'date': '2024-01-15',
#   'price': 453.95,
#   'product': 'Mouse',
#   'quantity': 3,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1075',
#   'date': '2024-05-18',
#   'price': 506.42,
#   'product': 'Keyboard',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1076',
#   'date': '2024-04-05',
#   'price': 1015.33,
#   'product': 'Phone',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1077',
#   'date': '2024-02-14',
#   'price': 1133.51,
#   'product': 'Phone',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1078',
#   'date': '2024-05-18',
#   'price': 1191.54,
#   'product': 'Monitor',
#   'quantity': 3,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1079',
#   'date': '2024-04-30',
#   'price': 1188.63,
#   'product': 'Phone',
#   'quantity': 3,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1080',
#   'date': '2024-01-04',
#   'price': 154.99,
#   'product': 'Phone',
#   'quantity': 1,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1081',
#   'date': '2024-06-01',
#   'price': 751.74,
#   'product': 'Mouse',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1082',
#   'date': '2024-06-13',
#   'price': 105.19,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1083',
#   'date': '2024-04-10',
#   'price': 833.3,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1084',
#   'date': '2024-05-28',
#   'price': 673.47,
#   'product': 'Mouse',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1085',
#   'date': '2024-03-28',
#   'price': 1333.8,
#   'product': 'Monitor',
#   'quantity': 1,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1086',
#   'date': '2024-06-03',
#   'price': 539.35,
#   'product': 'Laptop',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1087',
#   'date': '2024-01-06',
#   'price': 193.26,
#   'product': 'Mouse',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1088',
#   'date': '2024-01-01',
#   'price': 231.63,
#   'product': 'Keyboard',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1089',
#   'date': '2024-04-13',
#   'price': 1147.04,
#   'product': 'Keyboard',
#   'quantity': 4,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1090',
#   'date': '2024-05-23',
#   'price': 934.96,
#   'product': 'Phone',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1091',
#   'date': '2024-03-14',
#   'price': 169.66,
#   'product': 'Keyboard',
#   'quantity': 4,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1092',
#   'date': '2024-02-23',
#   'price': 144.48,
#   'product': 'Phone',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1093',
#   'date': '2024-06-13',
#   'price': 1057.43,
#   'product': 'Laptop',
#   'quantity': 3,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1094',
#   'date': '2024-06-01',
#   'price': 127.69,
#   'product': 'Monitor',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1095',
#   'date': '2024-05-21',
#   'price': 1236.35,
#   'product': 'Monitor',
#   'quantity': 4,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1096',
#   'date': '2024-02-02',
#   'price': 1065.24,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1097',
#   'date': '2024-05-05',
#   'price': 140.4,
#   'product': 'Keyboard',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1098',
#   'date': '2024-06-02',
#   'price': 145.56,
#   'product': 'Laptop',
#   'quantity': 4,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1099',
#   'date': '2024-06-21',
#   'price': 1480.23,
#   'product': 'Keyboard',
#   'quantity': 2,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1100',
#   'date': '2024-03-05',
#   'price': 573.92,
#   'product': 'Keyboard',
#   'quantity': 3,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1101',
#   'date': '2024-03-07',
#   'price': 568.55,
#   'product': 'Laptop',
#   'quantity': 4,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1102',
#   'date': '2024-02-04',
#   'price': 1222.94,
#   'product': 'Laptop',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1103',
#   'date': '2024-05-28',
#   'price': 1421.93,
#   'product': 'Laptop',
#   'quantity': 4,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1104',
#   'date': '2024-01-08',
#   'price': 1479.28,
#   'product': 'Laptop',
#   'quantity': 1,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1105',
#   'date': '2024-05-18',
#   'price': 1135.0,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1106',
#   'date': '2024-06-21',
#   'price': 576.86,
#   'product': 'Headphones',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1107',
#   'date': '2024-04-09',
#   'price': 143.58,
#   'product': 'Headphones',
#   'quantity': 2,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1108',
#   'date': '2024-02-07',
#   'price': 1170.18,
#   'product': 'Laptop',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1109',
#   'date': '2024-06-13',
#   'price': 846.44,
#   'product': 'Headphones',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1110',
#   'date': '2024-03-18',
#   'price': 647.85,
#   'product': 'Headphones',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1111',
#   'date': '2024-01-27',
#   'price': 1361.4,
#   'product': 'Laptop',
#   'quantity': 2,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1112',
#   'date': '2024-04-15',
#   'price': 184.57,
#   'product': 'Headphones',
#   'quantity': 3,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1113',
#   'date': '2024-01-19',
#   'price': 749.09,
#   'product': 'Keyboard',
#   'quantity': 2,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1114',
#   'date': '2024-02-08',
#   'price': 36.8,
#   'product': 'Phone',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1115',
#   'date': '2024-03-28',
#   'price': 713.62,
#   'product': 'Phone',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1116',
#   'date': '2024-02-10',
#   'price': 103.33,
#   'product': 'Laptop',
#   'quantity': 3,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1117',
#   'date': '2024-04-08',
#   'price': 195.85,
#   'product': 'Monitor',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1118',
#   'date': '2024-03-06',
#   'price': 193.94,
#   'product': 'Laptop',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1119',
#   'date': '2024-03-30',
#   'price': 980.83,
#   'product': 'Monitor',
#   'quantity': 4,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1120',
#   'date': '2024-01-16',
#   'price': 1124.15,
#   'product': 'Phone',
#   'quantity': 1,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1121',
#   'date': '2024-01-12',
#   'price': 883.39,
#   'product': 'Laptop',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1122',
#   'date': '2024-01-28',
#   'price': 1444.02,
#   'product': 'Mouse',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1123',
#   'date': '2024-02-21',
#   'price': 574.81,
#   'product': 'Keyboard',
#   'quantity': 1,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1124',
#   'date': '2024-04-18',
#   'price': 442.85,
#   'product': 'Headphones',
#   'quantity': 4,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1125',
#   'date': '2024-05-17',
#   'price': 1305.53,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1126',
#   'date': '2024-05-26',
#   'price': 350.92,
#   'product': 'Mouse',
#   'quantity': 2,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1127',
#   'date': '2024-04-14',
#   'price': 1445.57,
#   'product': 'Headphones',
#   'quantity': 1,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1128',
#   'date': '2024-04-01',
#   'price': 37.99,
#   'product': 'Headphones',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1129',
#   'date': '2024-01-28',
#   'price': 1455.42,
#   'product': 'Laptop',
#   'quantity': 1,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1130',
#   'date': '2024-03-08',
#   'price': 83.88,
#   'product': 'Headphones',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1131',
#   'date': '2024-06-23',
#   'price': 1338.89,
#   'product': 'Keyboard',
#   'quantity': 3,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1132',
#   'date': '2024-06-15',
#   'price': 801.0,
#   'product': 'Mouse',
#   'quantity': 2,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1133',
#   'date': '2024-03-27',
#   'price': 1489.59,
#   'product': 'Headphones',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1134',
#   'date': '2024-03-18',
#   'price': 129.22,
#   'product': 'Laptop',
#   'quantity': 2,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1135',
#   'date': '2024-04-10',
#   'price': 839.7,
#   'product': 'Keyboard',
#   'quantity': 3,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1136',
#   'date': '2024-04-20',
#   'price': 1454.57,
#   'product': 'Phone',
#   'quantity': 3,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1137',
#   'date': '2024-04-03',
#   'price': 794.18,
#   'product': 'Mouse',
#   'quantity': 3,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1138',
#   'date': '2024-04-20',
#   'price': 951.51,
#   'product': 'Headphones',
#   'quantity': 4,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1139',
#   'date': '2024-03-13',
#   'price': 1049.71,
#   'product': 'Laptop',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1140',
#   'date': '2024-02-07',
#   'price': 692.72,
#   'product': 'Phone',
#   'quantity': 1,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1141',
#   'date': '2024-04-09',
#   'price': 948.79,
#   'product': 'Phone',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1142',
#   'date': '2024-06-26',
#   'price': 884.79,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1143',
#   'date': '2024-06-04',
#   'price': 1353.71,
#   'product': 'Keyboard',
#   'quantity': 4,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1144',
#   'date': '2024-02-12',
#   'price': 87.26,
#   'product': 'Headphones',
#   'quantity': 2,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1145',
#   'date': '2024-03-20',
#   'price': 435.83,
#   'product': 'Laptop',
#   'quantity': 1,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1146',
#   'date': '2024-05-02',
#   'price': 1426.61,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1147',
#   'date': '2024-01-14',
#   'price': 1337.59,
#   'product': 'Keyboard',
#   'quantity': 1,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1148',
#   'date': '2024-01-09',
#   'price': 694.37,
#   'product': 'Monitor',
#   'quantity': 4,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1149',
#   'date': '2024-04-17',
#   'price': 937.8,
#   'product': 'Mouse',
#   'quantity': 3,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1150',
#   'date': '2024-04-24',
#   'price': 430.52,
#   'product': 'Keyboard',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1151',
#   'date': '2024-01-12',
#   'price': 298.42,
#   'product': 'Keyboard',
#   'quantity': 2,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1152',
#   'date': '2024-04-22',
#   'price': 706.27,
#   'product': 'Headphones',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1153',
#   'date': '2024-05-25',
#   'price': 542.96,
#   'product': 'Keyboard',
#   'quantity': 4,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1154',
#   'date': '2024-03-28',
#   'price': 883.81,
#   'product': 'Monitor',
#   'quantity': 4,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1155',
#   'date': '2024-01-08',
#   'price': 135.05,
#   'product': 'Keyboard',
#   'quantity': 1,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1156',
#   'date': '2024-02-06',
#   'price': 1462.1,
#   'product': 'Headphones',
#   'quantity': 2,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1157',
#   'date': '2024-03-05',
#   'price': 1479.59,
#   'product': 'Headphones',
#   'quantity': 2,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1158',
#   'date': '2024-03-01',
#   'price': 1053.28,
#   'product': 'Mouse',
#   'quantity': 4,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1159',
#   'date': '2024-03-13',
#   'price': 813.42,
#   'product': 'Monitor',
#   'quantity': 3,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1160',
#   'date': '2024-01-13',
#   'price': 478.1,
#   'product': 'Phone',
#   'quantity': 2,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1161',
#   'date': '2024-03-24',
#   'price': 1224.42,
#   'product': 'Phone',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1162',
#   'date': '2024-04-16',
#   'price': 1033.4,
#   'product': 'Keyboard',
#   'quantity': 4,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1163',
#   'date': '2024-06-07',
#   'price': 260.67,
#   'product': 'Mouse',
#   'quantity': 4,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1164',
#   'date': '2024-05-16',
#   'price': 1368.17,
#   'product': 'Laptop',
#   'quantity': 1,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1165',
#   'date': '2024-06-29',
#   'price': 1237.36,
#   'product': 'Keyboard',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1166',
#   'date': '2024-06-24',
#   'price': 1425.7,
#   'product': 'Mouse',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1167',
#   'date': '2024-03-09',
#   'price': 1094.06,
#   'product': 'Monitor',
#   'quantity': 1,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1168',
#   'date': '2024-06-09',
#   'price': 927.85,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1169',
#   'date': '2024-01-11',
#   'price': 639.0,
#   'product': 'Monitor',
#   'quantity': 1,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1170',
#   'date': '2024-04-01',
#   'price': 1400.44,
#   'product': 'Monitor',
#   'quantity': 4,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1171',
#   'date': '2024-03-05',
#   'price': 1301.77,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1172',
#   'date': '2024-05-14',
#   'price': 86.92,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1173',
#   'date': '2024-01-18',
#   'price': 59.02,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1174',
#   'date': '2024-04-10',
#   'price': 577.17,
#   'product': 'Headphones',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1175',
#   'date': '2024-01-13',
#   'price': 1219.62,
#   'product': 'Phone',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1176',
#   'date': '2024-06-26',
#   'price': 1481.17,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1177',
#   'date': '2024-04-25',
#   'price': 242.62,
#   'product': 'Laptop',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1178',
#   'date': '2024-06-02',
#   'price': 899.31,
#   'product': 'Mouse',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1179',
#   'date': '2024-06-12',
#   'price': 583.72,
#   'product': 'Laptop',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1180',
#   'date': '2024-06-10',
#   'price': 1455.47,
#   'product': 'Laptop',
#   'quantity': 4,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1181',
#   'date': '2024-02-28',
#   'price': 1266.34,
#   'product': 'Laptop',
#   'quantity': 2,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1182',
#   'date': '2024-04-30',
#   'price': 1260.73,
#   'product': 'Headphones',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1183',
#   'date': '2024-05-28',
#   'price': 713.67,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1184',
#   'date': '2024-03-14',
#   'price': 633.93,
#   'product': 'Laptop',
#   'quantity': 1,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1185',
#   'date': '2024-05-21',
#   'price': 424.64,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1186',
#   'date': '2024-05-05',
#   'price': 103.44,
#   'product': 'Keyboard',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1187',
#   'date': '2024-05-08',
#   'price': 1299.79,
#   'product': 'Laptop',
#   'quantity': 1,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1188',
#   'date': '2024-01-22',
#   'price': 1223.09,
#   'product': 'Headphones',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1189',
#   'date': '2024-06-29',
#   'price': 1499.58,
#   'product': 'Mouse',
#   'quantity': 2,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1190',
#   'date': '2024-05-11',
#   'price': 1495.02,
#   'product': 'Headphones',
#   'quantity': 2,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1191',
#   'date': '2024-06-15',
#   'price': 842.04,
#   'product': 'Laptop',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1192',
#   'date': '2024-05-01',
#   'price': 1158.1,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1193',
#   'date': '2024-01-29',
#   'price': 1418.25,
#   'product': 'Keyboard',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1194',
#   'date': '2024-03-23',
#   'price': 1277.48,
#   'product': 'Laptop',
#   'quantity': 4,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1195',
#   'date': '2024-06-12',
#   'price': 386.08,
#   'product': 'Headphones',
#   'quantity': 1,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1196',
#   'date': '2024-05-11',
#   'price': 686.81,
#   'product': 'Phone',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1197',
#   'date': '2024-02-07',
#   'price': 211.16,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1198',
#   'date': '2024-06-21',
#   'price': 1432.0,
#   'product': 'Headphones',
#   'quantity': 1,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1199',
#   'date': '2024-04-23',
#   'price': 917.14,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1200',
#   'date': '2024-01-25',
#   'price': 358.39,
#   'product': 'Laptop',
#   'quantity': 1,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1201',
#   'date': '2024-01-05',
#   'price': 1014.12,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1202',
#   'date': '2024-02-19',
#   'price': 934.83,
#   'product': 'Laptop',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1203',
#   'date': '2024-03-22',
#   'price': 550.08,
#   'product': 'Mouse',
#   'quantity': 4,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1204',
#   'date': '2024-02-02',
#   'price': 188.07,
#   'product': 'Laptop',
#   'quantity': 3,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1205',
#   'date': '2024-02-04',
#   'price': 1013.93,
#   'product': 'Phone',
#   'quantity': 1,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1206',
#   'date': '2024-06-21',
#   'price': 790.06,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1207',
#   'date': '2024-04-26',
#   'price': 1163.03,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1208',
#   'date': '2024-02-25',
#   'price': 789.84,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1209',
#   'date': '2024-05-08',
#   'price': 1281.23,
#   'product': 'Phone',
#   'quantity': 3,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1210',
#   'date': '2024-03-02',
#   'price': 836.82,
#   'product': 'Headphones',
#   'quantity': 1,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1211',
#   'date': '2024-03-21',
#   'price': 850.19,
#   'product': 'Laptop',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1212',
#   'date': '2024-04-23',
#   'price': 1317.45,
#   'product': 'Keyboard',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1213',
#   'date': '2024-05-05',
#   'price': 617.15,
#   'product': 'Laptop',
#   'quantity': 3,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1214',
#   'date': '2024-03-08',
#   'price': 218.34,
#   'product': 'Laptop',
#   'quantity': 4,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1215',
#   'date': '2024-03-07',
#   'price': 62.6,
#   'product': 'Headphones',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1216',
#   'date': '2024-01-31',
#   'price': 1137.6,
#   'product': 'Laptop',
#   'quantity': 4,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1217',
#   'date': '2024-06-19',
#   'price': 938.06,
#   'product': 'Phone',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1218',
#   'date': '2024-03-21',
#   'price': 1062.04,
#   'product': 'Phone',
#   'quantity': 1,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1219',
#   'date': '2024-06-25',
#   'price': 335.19,
#   'product': 'Monitor',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1220',
#   'date': '2024-02-25',
#   'price': 221.83,
#   'product': 'Mouse',
#   'quantity': 3,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1221',
#   'date': '2024-06-04',
#   'price': 41.53,
#   'product': 'Keyboard',
#   'quantity': 2,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1222',
#   'date': '2024-03-08',
#   'price': 538.87,
#   'product': 'Laptop',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1223',
#   'date': '2024-01-13',
#   'price': 893.08,
#   'product': 'Laptop',
#   'quantity': 1,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1224',
#   'date': '2024-03-21',
#   'price': 600.52,
#   'product': 'Headphones',
#   'quantity': 2,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1225',
#   'date': '2024-06-29',
#   'price': 667.46,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1226',
#   'date': '2024-05-11',
#   'price': 1358.15,
#   'product': 'Phone',
#   'quantity': 4,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1227',
#   'date': '2024-04-27',
#   'price': 535.42,
#   'product': 'Keyboard',
#   'quantity': 2,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1228',
#   'date': '2024-03-15',
#   'price': 780.7,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1229',
#   'date': '2024-05-22',
#   'price': 1179.81,
#   'product': 'Phone',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1230',
#   'date': '2024-03-15',
#   'price': 606.88,
#   'product': 'Mouse',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1231',
#   'date': '2024-06-27',
#   'price': 940.69,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1232',
#   'date': '2024-03-17',
#   'price': 1296.3,
#   'product': 'Headphones',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1233',
#   'date': '2024-02-10',
#   'price': 1425.29,
#   'product': 'Headphones',
#   'quantity': 2,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1234',
#   'date': '2024-05-18',
#   'price': 237.67,
#   'product': 'Laptop',
#   'quantity': 3,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1235',
#   'date': '2024-03-31',
#   'price': 1391.35,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1236',
#   'date': '2024-01-16',
#   'price': 748.33,
#   'product': 'Keyboard',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1237',
#   'date': '2024-03-12',
#   'price': 402.2,
#   'product': 'Monitor',
#   'quantity': 1,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1238',
#   'date': '2024-05-23',
#   'price': 699.52,
#   'product': 'Phone',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1239',
#   'date': '2024-02-01',
#   'price': 1470.45,
#   'product': 'Mouse',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1240',
#   'date': '2024-01-02',
#   'price': 749.07,
#   'product': 'Mouse',
#   'quantity': 2,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1241',
#   'date': '2024-03-19',
#   'price': 506.55,
#   'product': 'Headphones',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1242',
#   'date': '2024-04-16',
#   'price': 957.43,
#   'product': 'Laptop',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1243',
#   'date': '2024-03-30',
#   'price': 375.42,
#   'product': 'Laptop',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1244',
#   'date': '2024-06-20',
#   'price': 132.28,
#   'product': 'Monitor',
#   'quantity': 4,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1245',
#   'date': '2024-01-23',
#   'price': 210.74,
#   'product': 'Headphones',
#   'quantity': 3,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1246',
#   'date': '2024-04-27',
#   'price': 209.51,
#   'product': 'Mouse',
#   'quantity': 4,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1247',
#   'date': '2024-03-03',
#   'price': 244.82,
#   'product': 'Keyboard',
#   'quantity': 4,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1248',
#   'date': '2024-02-15',
#   'price': 225.46,
#   'product': 'Headphones',
#   'quantity': 1,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1249',
#   'date': '2024-03-13',
#   'price': 968.49,
#   'product': 'Monitor',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1250',
#   'date': '2024-04-14',
#   'price': 289.18,
#   'product': 'Monitor',
#   'quantity': 3,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1251',
#   'date': '2024-04-06',
#   'price': 531.59,
#   'product': 'Headphones',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1252',
#   'date': '2024-02-21',
#   'price': 1347.25,
#   'product': 'Monitor',
#   'quantity': 3,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1253',
#   'date': '2024-06-01',
#   'price': 721.46,
#   'product': 'Headphones',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1254',
#   'date': '2024-01-25',
#   'price': 1007.99,
#   'product': 'Phone',
#   'quantity': 2,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1255',
#   'date': '2024-06-06',
#   'price': 275.03,
#   'product': 'Headphones',
#   'quantity': 3,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1256',
#   'date': '2024-03-25',
#   'price': 304.59,
#   'product': 'Headphones',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1257',
#   'date': '2024-06-05',
#   'price': 80.49,
#   'product': 'Monitor',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1258',
#   'date': '2024-05-16',
#   'price': 270.02,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1259',
#   'date': '2024-06-12',
#   'price': 432.31,
#   'product': 'Laptop',
#   'quantity': 2,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1260',
#   'date': '2024-05-23',
#   'price': 281.98,
#   'product': 'Laptop',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1261',
#   'date': '2024-06-11',
#   'price': 151.28,
#   'product': 'Phone',
#   'quantity': 4,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1262',
#   'date': '2024-05-15',
#   'price': 198.54,
#   'product': 'Laptop',
#   'quantity': 1,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1263',
#   'date': '2024-04-23',
#   'price': 701.95,
#   'product': 'Headphones',
#   'quantity': 2,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1264',
#   'date': '2024-06-08',
#   'price': 325.37,
#   'product': 'Monitor',
#   'quantity': 4,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1265',
#   'date': '2024-02-11',
#   'price': 559.12,
#   'product': 'Laptop',
#   'quantity': 3,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1266',
#   'date': '2024-02-28',
#   'price': 765.06,
#   'product': 'Laptop',
#   'quantity': 4,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1267',
#   'date': '2024-01-20',
#   'price': 1041.78,
#   'product': 'Phone',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1268',
#   'date': '2024-01-16',
#   'price': 78.18,
#   'product': 'Mouse',
#   'quantity': 3,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1269',
#   'date': '2024-03-10',
#   'price': 1203.13,
#   'product': 'Phone',
#   'quantity': 4,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1270',
#   'date': '2024-04-04',
#   'price': 949.29,
#   'product': 'Headphones',
#   'quantity': 3,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1271',
#   'date': '2024-03-25',
#   'price': 141.0,
#   'product': 'Monitor',
#   'quantity': 1,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1272',
#   'date': '2024-03-27',
#   'price': 1312.9,
#   'product': 'Phone',
#   'quantity': 2,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1273',
#   'date': '2024-04-25',
#   'price': 1382.89,
#   'product': 'Laptop',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1274',
#   'date': '2024-04-30',
#   'price': 110.4,
#   'product': 'Monitor',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1275',
#   'date': '2024-06-05',
#   'price': 429.78,
#   'product': 'Monitor',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1276',
#   'date': '2024-03-01',
#   'price': 1213.18,
#   'product': 'Laptop',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1277',
#   'date': '2024-06-16',
#   'price': 1127.42,
#   'product': 'Phone',
#   'quantity': 1,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1278',
#   'date': '2024-02-19',
#   'price': 293.09,
#   'product': 'Laptop',
#   'quantity': 2,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1279',
#   'date': '2024-03-26',
#   'price': 329.84,
#   'product': 'Mouse',
# ...
#   'product': 'Monitor',
#   'quantity': 1,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1406',
#   'date': '2024-02-17',
#   'price': 1361.58,
#   'product': 'Laptop',
#   'quantity': 2,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1407',
#   'date': '2024-06-18',
#   'price': 943.87,
#   'product': 'Mouse',
#   'quantity': 4,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1408',
#   'date': '2024-04-15',
#   'price': 193.01,
#   'product': 'Mouse',
#   'quantity': 2,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1409',
#   'date': '2024-03-24',
#   'price': 1410.95,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1410',
#   'date': '2024-04-25',
#   'price': 949.01,
#   'product': 'Headphones',
#   'quantity': 3,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1411',
#   'date': '2024-03-18',
#   'price': 515.66,
#   'product': 'Monitor',
#   'quantity': 3,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1412',
#   'date': '2024-04-06',
#   'price': 226.12,
#   'product': 'Phone',
#   'quantity': 2,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1413',
#   'date': '2024-06-12',
#   'price': 1195.16,
#   'product': 'Phone',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1414',
#   'date': '2024-02-27',
#   'price': 937.71,
#   'product': 'Mouse',
#   'quantity': 2,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1415',
#   'date': '2024-03-10',
#   'price': 809.52,
#   'product': 'Headphones',
#   'quantity': 3,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1416',
#   'date': '2024-02-27',
#   'price': 1342.96,
#   'product': 'Laptop',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1417',
#   'date': '2024-05-25',
#   'price': 1187.12,
#   'product': 'Phone',
#   'quantity': 1,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1418',
#   'date': '2024-02-04',
#   'price': 244.48,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1419',
#   'date': '2024-06-11',
#   'price': 481.35,
#   'product': 'Keyboard',
#   'quantity': 2,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1420',
#   'date': '2024-05-25',
#   'price': 387.76,
#   'product': 'Mouse',
#   'quantity': 4,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1421',
#   'date': '2024-04-01',
#   'price': 1121.04,
#   'product': 'Phone',
#   'quantity': 4,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1422',
#   'date': '2024-06-08',
#   'price': 69.63,
#   'product': 'Phone',
#   'quantity': 3,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1423',
#   'date': '2024-03-16',
#   'price': 863.44,
#   'product': 'Mouse',
#   'quantity': 3,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1424',
#   'date': '2024-04-02',
#   'price': 1148.44,
#   'product': 'Laptop',
#   'quantity': 3,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1425',
#   'date': '2024-03-28',
#   'price': 1317.61,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1426',
#   'date': '2024-06-16',
#   'price': 526.28,
#   'product': 'Phone',
#   'quantity': 4,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1427',
#   'date': '2024-01-06',
#   'price': 1235.46,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1428',
#   'date': '2024-04-14',
#   'price': 183.73,
#   'product': 'Mouse',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1429',
#   'date': '2024-04-17',
#   'price': 1272.75,
#   'product': 'Headphones',
#   'quantity': 1,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1430',
#   'date': '2024-01-07',
#   'price': 208.68,
#   'product': 'Monitor',
#   'quantity': 1,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1431',
#   'date': '2024-02-22',
#   'price': 607.99,
#   'product': 'Keyboard',
#   'quantity': 2,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1432',
#   'date': '2024-05-14',
#   'price': 1200.0,
#   'product': 'Laptop',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1433',
#   'date': '2024-02-21',
#   'price': 241.88,
#   'product': 'Keyboard',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1434',
#   'date': '2024-05-27',
#   'price': 359.29,
#   'product': 'Monitor',
#   'quantity': 1,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1435',
#   'date': '2024-06-24',
#   'price': 1088.93,
#   'product': 'Monitor',
#   'quantity': 4,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1436',
#   'date': '2024-01-07',
#   'price': 1085.65,
#   'product': 'Monitor',
#   'quantity': 4,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1437',
#   'date': '2024-02-17',
#   'price': 968.9,
#   'product': 'Keyboard',
#   'quantity': 4,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1438',
#   'date': '2024-04-21',
#   'price': 1047.04,
#   'product': 'Monitor',
#   'quantity': 3,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1439',
#   'date': '2024-05-30',
#   'price': 823.23,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1440',
#   'date': '2024-06-29',
#   'price': 392.66,
#   'product': 'Keyboard',
#   'quantity': 2,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1441',
#   'date': '2024-04-03',
#   'price': 531.63,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1442',
#   'date': '2024-04-08',
#   'price': 288.76,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1443',
#   'date': '2024-03-30',
#   'price': 1364.51,
#   'product': 'Headphones',
#   'quantity': 3,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1444',
#   'date': '2024-01-09',
#   'price': 883.42,
#   'product': 'Monitor',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1445',
#   'date': '2024-04-22',
#   'price': 613.26,
#   'product': 'Keyboard',
#   'quantity': 4,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1446',
#   'date': '2024-01-06',
#   'price': 703.77,
#   'product': 'Phone',
#   'quantity': 1,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1447',
#   'date': '2024-04-16',
#   'price': 1421.98,
#   'product': 'Monitor',
#   'quantity': 1,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1448',
#   'date': '2024-03-23',
#   'price': 246.96,
#   'product': 'Phone',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1449',
#   'date': '2024-01-03',
#   'price': 887.62,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1450',
#   'date': '2024-02-26',
#   'price': 768.72,
#   'product': 'Headphones',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1451',
#   'date': '2024-02-26',
#   'price': 924.95,
#   'product': 'Laptop',
#   'quantity': 1,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1452',
#   'date': '2024-01-21',
#   'price': 46.8,
#   'product': 'Headphones',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1453',
#   'date': '2024-02-19',
#   'price': 1310.74,
#   'product': 'Monitor',
#   'quantity': 4,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1454',
#   'date': '2024-02-12',
#   'price': 1399.54,
#   'product': 'Phone',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1455',
#   'date': '2024-03-13',
#   'price': 856.4,
#   'product': 'Phone',
#   'quantity': 2,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1456',
#   'date': '2024-04-06',
#   'price': 1051.04,
#   'product': 'Keyboard',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1457',
#   'date': '2024-02-05',
#   'price': 1385.3,
#   'product': 'Phone',
#   'quantity': 2,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1458',
#   'date': '2024-02-26',
#   'price': 1066.71,
#   'product': 'Keyboard',
#   'quantity': 2,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1459',
#   'date': '2024-02-06',
#   'price': 245.76,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1460',
#   'date': '2024-05-14',
#   'price': 872.91,
#   'product': 'Laptop',
#   'quantity': 1,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1461',
#   'date': '2024-04-15',
#   'price': 917.94,
#   'product': 'Monitor',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1462',
#   'date': '2024-04-19',
#   'price': 647.71,
#   'product': 'Keyboard',
#   'quantity': 1,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1463',
#   'date': '2024-02-19',
#   'price': 1109.94,
#   'product': 'Laptop',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1464',
#   'date': '2024-01-24',
#   'price': 1402.86,
#   'product': 'Phone',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1465',
#   'date': '2024-02-02',
#   'price': 1389.84,
#   'product': 'Phone',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1466',
#   'date': '2024-05-23',
#   'price': 687.24,
#   'product': 'Laptop',
#   'quantity': 1,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1467',
#   'date': '2024-05-13',
#   'price': 187.59,
#   'product': 'Phone',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1468',
#   'date': '2024-04-30',
#   'price': 1477.56,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1469',
#   'date': '2024-03-22',
#   'price': 1261.57,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1470',
#   'date': '2024-06-27',
#   'price': 204.5,
#   'product': 'Laptop',
#   'quantity': 4,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1471',
#   'date': '2024-03-15',
#   'price': 1382.85,
#   'product': 'Keyboard',
#   'quantity': 4,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1472',
#   'date': '2024-06-16',
#   'price': 1307.45,
#   'product': 'Keyboard',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1473',
#   'date': '2024-05-04',
#   'price': 787.88,
#   'product': 'Laptop',
#   'quantity': 3,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1474',
#   'date': '2024-02-28',
#   'price': 895.09,
#   'product': 'Keyboard',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1475',
#   'date': '2024-05-20',
#   'price': 610.52,
#   'product': 'Keyboard',
#   'quantity': 1,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1476',
#   'date': '2024-02-12',
#   'price': 101.05,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1477',
#   'date': '2024-03-02',
#   'price': 516.09,
#   'product': 'Keyboard',
#   'quantity': 1,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1478',
#   'date': '2024-01-19',
#   'price': 1208.22,
#   'product': 'Headphones',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1479',
#   'date': '2024-03-22',
#   'price': 26.86,
#   'product': 'Monitor',
#   'quantity': 4,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1480',
#   'date': '2024-03-21',
#   'price': 513.58,
#   'product': 'Phone',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1481',
#   'date': '2024-03-01',
#   'price': 609.29,
#   'product': 'Headphones',
#   'quantity': 3,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1482',
#   'date': '2024-02-25',
#   'price': 815.35,
#   'product': 'Keyboard',
#   'quantity': 4,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1483',
#   'date': '2024-04-20',
#   'price': 1381.39,
#   'product': 'Mouse',
#   'quantity': 3,
#   'shipping_city': 'Toronto'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1484',
#   'date': '2024-02-08',
#   'price': 532.59,
#   'product': 'Laptop',
#   'quantity': 2,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1485',
#   'date': '2024-02-17',
#   'price': 533.49,
#   'product': 'Keyboard',
#   'quantity': 4,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1486',
#   'date': '2024-03-27',
#   'price': 1111.5,
#   'product': 'Mouse',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1487',
#   'date': '2024-02-21',
#   'price': 689.28,
#   'product': 'Monitor',
#   'quantity': 2,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1488',
#   'date': '2024-03-04',
#   'price': 352.42,
#   'product': 'Keyboard',
#   'quantity': 1,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1489',
#   'date': '2024-04-28',
#   'price': 689.61,
#   'product': 'Laptop',
#   'quantity': 2,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1490',
#   'date': '2024-02-26',
#   'price': 228.47,
#   'product': 'Mouse',
#   'quantity': 1,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1491',
#   'date': '2024-06-19',
#   'price': 281.05,
#   'product': 'Mouse',
#   'quantity': 3,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': nan,
#   'customer_id': 'CUST1492',
#   'date': '2024-05-04',
#   'price': 757.58,
#   'product': 'Mouse',
#   'quantity': 4,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1493',
#   'date': '2024-03-15',
#   'price': 640.01,
#   'product': 'Monitor',
#   'quantity': 4,
#   'shipping_city': 'Vancouver'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1494',
#   'date': '2024-03-11',
#   'price': 1373.97,
#   'product': 'Keyboard',
#   'quantity': 3,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'OFF20',
#   'customer_id': 'CUST1495',
#   'date': '2024-03-27',
#   'price': 556.34,
#   'product': 'Monitor',
#   'quantity': 4,
#   'shipping_city': 'Montreal'},
#  {'coupon_code': 'WELCOME15',
#   'customer_id': 'CUST1496',
#   'date': '2024-03-13',
#   'price': 879.27,
#   'product': 'Phone',
#   'quantity': 4,
#   'shipping_city': 'Ottawa'},
#  {'coupon_code': 'SAVE10',
#   'customer_id': 'CUST1497',
#   'date': '2024-06-13',
#   'price': 955.75,
#   'product': 'Phone',
#   'quantity': 1,
#   'shipping_city': 'Calgary'},
#  {'coupon_code': 'DISCOUNT5',
#   'customer_id': 'CUST1498',
#   'date': '2024-03-07',
#   'price': 39.38,
#   'product': 'Keyboard',
#   'quantity': 3,
#   'shipping_city': 'Ottawa'}]

# %% [markdown]
# ## Step 5 – Quick Profiling

# %%
min_price = df_step3['price'].min()
mean_price = df_step3['price'].mean()
max_price = df_step3['price'].max()

unique_cities = set(df_step3['shipping_city'])
min_price, mean_price, max_price, len(unique_cities)
# Out:
# (np.float64(25.0), np.float64(373.92601333333334), np.float64(1499.58), 6)

# %% [markdown]
# ## Step 6 – Spot the Grime
# Missing values, zero/negative quantities, and inconsistent coupon codes.

# %% [markdown]
# ## Step 7 – Cleaning Rules

# %%
before_rows = len(df_raw)
df_clean = df_raw.dropna(subset=['price', 'quantity'])
df_clean = df_clean[df_clean['quantity'] > 0]
after_rows = len(df_clean)
before_rows, after_rows
# Out:
# (1500, 1500)

# %% [markdown]
# ## Step 8 – Transformations

# %%
def parse_discount(code):
    if pd.isna(code):
        return 0
    digits = ''.join(filter(str.isdigit, str(code)))
    return int(digits) if digits else 0

df_clean['discount_percent'] = df_clean['coupon_code'].apply(parse_discount)
df_clean[['coupon_code', 'discount_percent']].head()
# Out:
#   coupon_code  discount_percent
# 0   WELCOME15                15
# 1   DISCOUNT5                 5
# 2   WELCOME15                15
# 3       OFF20                20
# 4   DISCOUNT5                 5

# %% [markdown]
# ## Step 9 – Feature Engineering

# %%
df_clean['order_date'] = pd.to_datetime(df_clean['date'])
latest_date = df_clean['order_date'].max()
df_clean['days_since_purchase'] = (latest_date - df_clean['order_date']).dt.days

# %% [markdown]
# ## Step 10 – Mini-Aggregation

# %%
df_clean['revenue'] = df_clean['price'] * df_clean['quantity']
revenue_by_city = df_clean.groupby('shipping_city')['revenue'].sum().to_dict()
list(revenue_by_city.items())[:5]
# Out:
# [('Calgary', 161850.34),
#  ('Montreal', 184951.42),
#  ('Ottawa', 217806.6),
#  ('Toronto', 198684.23),
#  ('Vancouver', 177339.7)]

# %% [markdown]
# ## Step 11 – Serialization Checkpoint

# %%
df_clean.to_csv('data/cleaned_sales.csv', index=False)
df_clean.to_json('data/cleaned_sales.json', orient='records', indent=2)
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_2300\3923981207.py:2: Pandas4Warning: The default 'epoch' date format is deprecated and will be removed in a future version, please use 'iso' date format instead.
#   df_clean.to_json('data/cleaned_sales.json', orient='records', indent=2)

# %% [markdown]
# ## Step 12 – Soft Interview Reflection
# Functions and classes helped modularize the data-cleaning logic, making the workflow reusable, readable, and easier to maintain.

# %% [markdown]
# ## Data Dictionary
# | Field | Type | Description | Source |
# |------|------|------------|--------|
# | date | Date | Order date | Primary CSV |
# | customer_id | String | Customer identifier | Primary CSV |
# | product | String | Product name | Primary CSV |
# | price | Float | Unit price | Primary CSV |
# | quantity | Integer | Quantity purchased | Primary CSV |
# | coupon_code | String | Promo code | Primary CSV |
# | discount_percent | Integer | Parsed discount | Derived |
# | shipping_city | String | Delivery city | Primary CSV |
# | days_since_purchase | Integer | Days since order | Synthetic |
